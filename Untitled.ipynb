# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import researchpy as rp
import statsmodels.api as sm
import scipy.stats as stats

with open('ac_hmda_2018-2021.csv', 'r', encoding='utf-8-sig') as f:
    reader = csv.DictReader(f)
    rows = list(reader)

census_tracts = set()
for row in rows:
    census_tracts.add(row['census_tract'])

# %%
import sys
# !{sys.executable} -m pip install researchpy
# Out:
# Collecting researchpy
#   Using cached researchpy-0.3.5-py3-none-any.whl (33 kB)
# Requirement already satisfied: numpy in c:\users\ror88\anaconda3\lib\site-packages (from researchpy) (1.20.3)
# Requirement already satisfied: pandas in c:\users\ror88\anaconda3\lib\site-packages (from researchpy) (1.3.4)
# Requirement already satisfied: scipy in c:\users\ror88\anaconda3\lib\site-packages (from researchpy) (1.7.1)
# Requirement already satisfied: patsy in c:\users\ror88\anaconda3\lib\site-packages (from researchpy) (0.5.2)
# Requirement already satisfied: statsmodels in c:\users\ror88\anaconda3\lib\site-packages (from researchpy) (0.12.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ror88\anaconda3\lib\site-packages (from pandas->researchpy) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\ror88\anaconda3\lib\site-packages (from pandas->researchpy) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\ror88\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->researchpy) (1.16.0)
# Installing collected packages: researchpy
# Successfully installed researchpy-0.3.5

# %%
fields_to_use = ['derived_race', 'income', 'loan_amount', 'derived_sex', "debt_to_income_ratio"] #derived_loan_product_type', 'derived_dwelling_category'
xs_dict_all_years = {}
ys_dict_all_years = {}
census_tracts_list = list(census_tracts)
census_tracts_list = sorted(census_tracts_list)
group_1 = ["36", "37", "38", "39", "40"]
group_2 = ["41","42","43","44","45","47"]
group_3 = ["47", "48","49","50%-60%",">60%"]
all_data=[]
for tract in (census_tracts_list):
    us = []
    vs = []
    ps = []
    qs = []
    for row in rows:
        if row['census_tract'] == tract:
            values = []
            for field in fields_to_use:
                if field == 'income':
                    if row[field] == "NA":
                        pass
                    else:
                        values.append(int(row[field]))
                if field == 'derived_race':
                    if row[field] == 'White':
                        values.append(0)
                    elif row[field] == 'Black or African American':
                        values.append(1)
                elif field == 'derived_sex':
                    if row[field] == 'Female':
                        values.append(0)
                    elif row[field] == 'Male':
                        values.append(1)
                elif field == 'loan_amount':
                    values.append(int(row[field]))
                elif field == 'debt_to_income_ratio':
                    if row[field] == '<20%':
                        values.append(1)
                    elif row[field] == '20%-<30%':
                        values.append(2)
                    elif row[field] == '30%-<36%':
                        values.append(3)
                    elif row[field] in group_1:
                        values.append(4)
                    elif row[field] in group_2:
                        values.append(5)
                    elif row[field] in group_3:
                        values.append(6)
                    else:
                        pass
            if len(values) == len(fields_to_use):
                ps = []
                us.append(values)
                ps.append(row['census_tract'])
                for item in values:
                    ps.append(item)
                field = 'action_taken'
                if row[field] == '3':
                    vs.append(0)
                    ps.append(0)
                elif row[field] == '1':
                    vs.append(1)
                    ps.append(1)
                all_data.append(np.array(ps))
            ys_dict_all_years[row['census_tract']] = np.array(vs)
            xs_dict_all_years[row['census_tract']] = np.array(us)


reduced_xs = {}
reduced_ys = {}

for tract in xs_dict_all_years:
    if len(xs_dict_all_years[tract]) <=5:
        pass
    elif len(ys_dict_all_years[tract]) == np.sum(ys_dict_all_years[tract]):
        pass
    else:
        reduced_xs[tract] = xs_dict_all_years[tract]
        reduced_ys[tract] = ys_dict_all_years[tract]

# %%
headers = ['tract']
headers.extend(fields_to_use)
headers.append('outcome')

# %%
import pandas as pd
mort_df = pd.DataFrame(all_data, columns=headers)

# %%
rp.summary_cont(mort_df.groupby(["tract", "derived_race"])['outcome'])
# Out:
# C:\Users\ror88\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# C:\Users\ror88\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in add
#   lower_bound = _a * scale + loc
# C:\Users\ror88\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc
#                            N          Mean      SD      SE     95% Conf.  \
# tract       derived_race
# 42003010300 0              5  2.000000e-01  0.4472  0.2000 -3.553000e-01
# 42003020100 0             67  1.658360e+64  0.3436  0.0420  1.658360e+64
#             1             10  1.001111e+08  0.5164  0.1633  1.001111e+08
# 42003020300 0             66  1.683502e+63  0.2099  0.0258  1.683502e+63
#             1              3  3.700000e+01  0.0000  0.0000           NaN
# ...                       ..           ...     ...     ...           ...
# 42003980400 1              1  1.000000e+00     NaN     NaN           NaN
# 42003980600 0              1  1.000000e+00     NaN     NaN           NaN
# 42003980700 0              1  0.000000e+00     NaN     NaN           NaN
# 42003981000 1              1  0.000000e+00     NaN     NaN           NaN
# 42003982200 0              2  5.500000e+00  0.0000  0.0000           NaN
#
#                               Interval
# tract       derived_race
# 42003010300 0             7.553000e-01
# 42003020100 0             1.658360e+64
#             1             1.001111e+08
# 42003020300 0             1.683502e+63
#             1                      NaN
# ...                                ...
# 42003980400 1                      NaN
# 42003980600 0                      NaN
# 42003980700 0                      NaN
# 42003981000 1                      NaN
# 42003982200 0                      NaN
#
# [731 rows x 6 columns]
